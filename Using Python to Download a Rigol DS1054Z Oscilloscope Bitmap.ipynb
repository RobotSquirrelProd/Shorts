# %% [markdown]
# ### Using Python to Download a Rigol DS1054Z Oscilloscope Bitmap

# %% [markdown]
# More content like this can be found at [robotsquirrelproductions.com](https://robotsquirrelproductions.com/)

# %% [markdown]
# ### Import the libraries and packages needed.

# %% [markdown]
# The lines below document the version of python used in this example

# %%
import sys
print(sys.version)

# %%
from ds1054z import DS1054Z
import matplotlib.pyplot as plt
from matplotlib.ticker import FormatStrFormatter
import numpy as np

# %%
from IPython.display import Image, display

# %%
scope = DS1054Z('192.168.1.206')
print(scope.idn)
# Out:
# RIGOL TECHNOLOGIES,DS1054Z,DS1ZA200902668,00.04.04.SP3

# %%
scope.run()

# %%
bmap_scope = scope.display_data
display(Image(bmap_scope))

# %%
scope.set_channel_scale(1, 0.5)

# %%
bmap_scope = scope.display_data
display(Image(bmap_scope))
